# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Multi-Dimensional Scaling**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# ## Use cases of Multi-Dimensional Scaling
#
# *   Recognizing families of parts in order to design cellular manufacturing systems.
# *   Creating groups of products when designing assembly areas.
# *   Market research, multi-dimensional scaling is often used to plot data such as the perception of products in an easy to interpret, visual way.
#
# For instance, suppose a realtor has many listings to sell. Each listing has several attributes such as number of bedrooms, number of bathrooms, square feet, etc. You as a Data Scientist, are hired by the realtor to find out the similarities and dissimilarities of the listings, so that the brokers can use this information when providing recommendations for the buyers.
#
# However, since the number of attributes each listing has is bigger than what could be visualized, to have a clearer sense of how different each listing is you would need to reproduce the listing data on a lower dimension.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/images/realtor.jpeg" width=60%>

# %% [markdown]
# Multi-Dimensional Scaling (MDS) is a family of algorithms, one version of which is Principal Component Analysis (PCA). Like PCA, MDS can be used for dimensionality reduction; MDS can also be used to map complex differences into visual space. Additional articles on MDS:   <a href="https://link.springer.com/chapter/10.1007/978-3-642-82580-4_139?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01"> \[1]</a>, <a href="https://www.djsresearch.co.uk/glossary/item/Multi-Dimensional-Scaling?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01"> \[2]</a>
#
# There are several different categories of Multidimensional scaling (MDS). In this lab, we will review  Metric MDS as well as Non-Metric MDS scaling using **scikit-learn** library. For more information on MDS, please see <a href="https://arxiv.org/pdf/2009.08136.pdf?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01"> \[3]</a>.

# %% [markdown]
# Steps in MDS analysis:
#
# *   Pre-process and generate training and testing datasets
# *   Train and fine-tune logistic regression models
# *   Interpret trained logistic regression models
# *   Evaluate trained logistic regression models

# %% [markdown]
# ## **Table of Contents**
#
# <ol>
#     <li><a href="https://#Objectives">Objectives</a></li>
#     <li><a href="https://#Datasets">Datasets</a></li>
#     <li>
#         <a href="https://#Setup">Setup</a>
#         <ol>
#             <li><a href="https://#Installing-Required-Libraries">Installing Required Libraries</a></li>
#             <li><a href="https://#Importing-Required-Libraries">Importing Required Libraries</a></li>
#             <li><a href="https://#Defining-Helper-Functions">Defining-Helper-Functions</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="https://#Metric-MDS">Metric MDS</a>
#         <ol>
#             <li><a href="https://#From-Relative-Location-to-Absolute-Location">From Relative Location to Absolute Location</a></li>
#             <li><a href="https://#Example-1">Example 1</a></li>
#         </ol>
#     </li>
#     <li><a href="https://#Non-Metric-MDS">Non-Metric MDS</a></li>
#     <li>
#         <a href="https://#Dimensionality-reduction-with-MDS">Dimensionality reduction with MDS</a>
#         <ol>
#             <li><a href="https://#Exercise-1">Exercise 1 </a></li>
#         </ol>
#     </li>
#     <li><a href="https://#T-Distributed-Stochastic-Neighbor-Embedding-(optional)">T-Distributed Stochastic Neighbor Embedding (optional)</a></li>
# </ol>

# %% [markdown]
# ***

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be able to:

# %% [markdown]
# *   **Understand** different types of Multi-Dimensional Scaling
# *   **Understand** concepts of Metric MDS and Non-Metric MDS, including: embedding space, minimization and Stress
# *   **Apply**  Metric-MDS and Non-Metric MDS
# *   **Apply** different distance metrics to  Metric MDS and Non-Metric MDS
# *   **Apply**  MDS to dimensionality reduction

# %% [markdown]
# ## Datasets
#
# Datasets for this lab are gathered from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01) under the MIT License.

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`pandas`](https://pandas.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01) for managing the data.
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01) for mathematical operations.
# *   [`matplotlib`](https://matplotlib.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01) for visualizing the data.
# *   [`scipy`](https://docs.scipy.org/doc/scipy/reference/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01) for complex numerical operations.
# *   [`sklearn`](https://scikit-learn.org/stable/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01) for machine learning and machine-learning-pipeline related functions.

# %% [markdown]
# ### Installing Required Libraries
#
# The following required modules are pre-installed in the Skills Network Labs environment. However if you run this notebook commands in a different Jupyter environment (e.g. Watson Studio or Ananconda) you will need to install these libraries by removing the `#` sign before `!mamba` in the code cell below.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
#!mamba install -qy pandas==1.3.4 numpy==1.21.4 matplotlib==3.5.0 scikit-learn==0.20.1 scipy==1.7.3
# Note: If your environment doesn't support "!mamba install", use "!pip install"

# %% [markdown]
# ### Importing Required Libraries

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

import pandas as pd
import numpy as np
from scipy.spatial.distance import euclidean, cityblock, cosine
import sklearn.metrics.pairwise
import seaborn as sns
import folium
# Import matplotlib for 3d plotting:
import matplotlib.pyplot as plt
from sklearn.preprocessing import  MinMaxScaler
from matplotlib import offsetbox
# Make matplotlib work in jupyter notebook
# %matplotlib inline

# %% [markdown]
# ### Defining Helper Functions

# %% [markdown]
# This function plots out labeled scatter plots of latitude and longitude data

# %%
def plot_points(df,color="red",title=""):

    X=df['lon']
    Y=df['lat']

    annotations=df.index

    plt.figure(figsize=(8,6))
    plt.scatter(X,Y,s=100,color=color)
    plt.title(title)
    plt.xlabel("lat")
    plt.ylabel("log")
    for i, label in enumerate(annotations):
        plt.annotate(label, (X[i], Y[i]))
    plt.axis('equal')
    plt.show()

# %% [markdown]
# This function plots out labelled scatter plots of digits dataset in two dimensions  after a Dimensionality reduction:

# %%
def plot_embedding(X, title, ax):
    X = MinMaxScaler().fit_transform(X)
    for digit in digits.target_names:
        ax.scatter(
            *X[y == digit].T,
            marker=f"${digit}$",
            s=60,
            color=plt.cm.Dark2(digit),
            alpha=0.425,
            zorder=2,
        )
    shown_images = np.array([[1.0, 1.0]])  # just something big
    for i in range(X.shape[0]):
        # plot every digit on the embedding
        # show an annotation box for a group of digits
        dist = np.sum((X[i] - shown_images) ** 2, 1)
        if np.min(dist) < 4e-3:
            # don't show points that are too close
            continue
        shown_images = np.concatenate([shown_images, [X[i]]], axis=0)
        imagebox = offsetbox.AnnotationBbox(
            offsetbox.OffsetImage(digits.images[i], cmap=plt.cm.gray_r), X[i]
        )
        imagebox.set(zorder=1)
        ax.add_artist(imagebox)

    ax.set_title(title)
    ax.axis("off")

# %% [markdown]
# ## Metric MDS

# %% [markdown]
# Metric MDS  represents points in an embedding space $\boldsymbol{Z}$  by preserving the distances $d\_{i,j}$ distance between $i-th $ and $j-th $ objects. Each distance is given by:

# %% [markdown]
# \begin{pmatrix}
# d\_{1,1} & d\_{1,2} & \cdots & d\_{1,N} \\\\\\\\
# d\_{2,1} & d\_{2,2} & \cdots & d\_{2,N} \\\\\\\\
# \vdots & \vdots & & \vdots \\\\\\\\
# d\_{N,1} & d\_{N,2} & \cdots & d\_{N,N}
# \end{pmatrix}.

# %% [markdown]
# For the distance $d\_{i,j}$ between objects $x_i$ and $x_j$,  we find corresponding points $z_i$ and $z_j$ that minimize the cost function called “**Stress**”, which is a residual sum of squares:

# %% [markdown]
# $\text{Stress}*D(z\_1,z\_2,...,z_N)=\Biggl(\sum*{i\ne j=1,...,N}\bigl(d\_{ij}-|z_i-z_j|\bigr)^2\Biggr)^{1/2}$

# %% [markdown]
# The goal is to find the embeddings   $z_i$ ,$z_j$ whose euclidean distance is most similar to the original $d\_{i,j}$. We will experiment with several different distance metrics for $d\_{i,j}$, and for the embedding space we can use any distance metric $d(z_i,z_j)$.  We will focus on the euclidean distance $d(z_i,z_j)= |z_i-z_j|$. For more check out <a href="https://arxiv.org/pdf/2009.08136.pdf?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01"> \[1]</a>.

# %% [markdown]
# ### From Relative Location to Absolute  Location

# %% [markdown]
# To better understand how MDS works, we would like to find the  position of several cities, given the length of the Relative latitude and longitude. Latitude is an angle that specifies the north–south position of a point on the Earth, which ranges from 0° at the Equator to 90° (North or South) at the poles. Lines of constant latitude, or parallels, run east–west as circles parallel to the equator. Longitude(λ) specifies the east–west position of a point on the Earth's surface, usually denoted by the Greek letter lambda (λ). Meridians (lines running from pole to pole) connect points with the same longitude as show here.

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/images/lat-log.png" width="300" alt="loglat"  />
# </center>

# %% [markdown]
# Latitude and longitude are calculated by examining celestial bodies' angles, sometimes in combination with time. We can calculate the difference between the angle relatively easily. This is shown in the figure below, where the boat and the city have different angles with the sun:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/images/Screen_Shot_2022-03-01_at_6.26.10_PM.png"  width="600" />
# </center>

# %% [markdown]
# To make things simpler, we will use angles between the cities. Here is the length of the relative latitude and longitude of several cities $d\_{ij}$.

# %%
distance=pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/distance.csv').set_index('name')
distance.head(8)
# Out:
#                 Buenos Aires  Paris  Melbourne  St Petersbourg  Abidjan  \
# name
# Buenos Aires            0.00  83.00       4.00           93.93    39.33
# Paris                  83.00   0.00      87.00           10.93    43.67
# Melbourne               4.00  87.00       0.00           97.93    43.33
# St Petersbourg         93.93  10.93      97.93            0.00    54.60
# Abidjan                39.33  43.67      43.33           54.60     0.00
# Montreal               79.52   3.48      83.52           14.41    40.19
# Nairobi                32.71  50.29      36.71           61.22     6.62
# Salvador               21.03  61.97      25.03           72.90    18.30
#
#                 Montreal  Nairobi  Salvador
# name
# Buenos Aires       79.52    32.71     21.03
# Paris               3.48    50.29     61.97
# Melbourne          83.52    36.71     25.03
# St Petersbourg     14.41    61.22     72.90
# Abidjan            40.19     6.62     18.30
# Montreal            0.00    46.81     58.49
# Nairobi            46.81     0.00     11.68
# Salvador           58.49    11.68      0.00

# %% [markdown]
# For Multidimensional Scaling in `sklearn`, we import the `MDS` constructor from the `manifold` module:

# %%
from sklearn.manifold import MDS

# %% [markdown]
# We create an MDS object `embedding` with the following parameters:

# %% [markdown]
# `n_components`: Number of dimensions in which to immerse the dissimilarities, default=2
#
# `precomputed`: Pre-computed dissimilarities are passed directly to **fit** and **fit_transform**
#
# `max_iter` : Maximum number of iterations of the <a href='https://scikit-learn.org/stable/modules/generated/sklearn.manifold.smacof.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01'> SMACOF</a> algorithm for a single run, default = 300
#
# `eps`: Relative tolerance with respect to stress at which to declare convergence, default=1e-3

# %%
embedding =  MDS(dissimilarity='precomputed',n_components=2,random_state=0,max_iter=300,eps=1e-3)

# %% [markdown]
# We apply `fit_transform` to the data from  `distance` array that fits the model and returns the embedded coordinates. The stress is minimized via  <a href='https://scikit-learn.org/stable/modules/generated/sklearn.manifold.smacof.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01'> SMACOF</a>.

# %%
X_transformed = embedding.fit_transform(distance)

# %% [markdown]
# We then plot the coordinates as an 'X_transformed'  approximation of the longitude and latitude.

# %%
df_t=pd.DataFrame(X_transformed , columns=["lon","lat"], index=distance.columns)
df_t.head(8)
# Out:
#                       lon        lat
# Buenos Aires   -11.186300 -41.802565
# Paris            9.513638  38.732017
# Melbourne       -9.292359 -46.088042
# St Petersbourg  16.549167  47.746633
# Abidjan         -1.608445  -3.575219
# Montreal         7.328738  35.794751
# Nairobi         -3.001616 -10.072240
# Salvador        -8.302824 -20.735334

# %% [markdown]
# We can also obtain the embeddings using the attribute `embedding_`.

# %%
embedding.embedding_
# Out:
# array([[-11.18630004, -41.80256455],
#        [  9.5136384 ,  38.73201664],
#        [ -9.2923592 , -46.08804169],
#        [ 16.54916736,  47.74663293],
#        [ -1.60844493,  -3.57521947],
#        [  7.3287376 ,  35.79475057],
#        [ -3.00161566, -10.07223994],
#        [ -8.30282353, -20.7353345 ]])

# %% [markdown]
# We can obtain the stress (sum of squared distance of the disparities and the distances for all constrained points).

# %%
embedding.stress_
# Out:
# np.float64(2.417240800968404)

# %% [markdown]
# Finally, we will use the pairwise `dissimilarity_matrix_` function.

# %%
embedding.dissimilarity_matrix_
# Out:
# array([[ 0.  , 83.  ,  4.  , 93.93, 39.33, 79.52, 32.71, 21.03],
#        [83.  ,  0.  , 87.  , 10.93, 43.67,  3.48, 50.29, 61.97],
#        [ 4.  , 87.  ,  0.  , 97.93, 43.33, 83.52, 36.71, 25.03],
#        [93.93, 10.93, 97.93,  0.  , 54.6 , 14.41, 61.22, 72.9 ],
#        [39.33, 43.67, 43.33, 54.6 ,  0.  , 40.19,  6.62, 18.3 ],
#        [79.52,  3.48, 83.52, 14.41, 40.19,  0.  , 46.81, 58.49],
#        [32.71, 50.29, 36.71, 61.22,  6.62, 46.81,  0.  , 11.68],
#        [21.03, 61.97, 25.03, 72.9 , 18.3 , 58.49, 11.68,  0.  ]])

# %% [markdown]
# Let’s compare the embeddings  to the longitude and latitude of each city.

# %%
# Make a data frame with dots to show on the map
df = pd.DataFrame({
   'lon':[-58, 2, 145, 30.32, -4.03, -73.57, 36.82, -38.5],
   'lat':[-34, 49, -38, 59.93, 5.33, 45.52, -1.29, -12.97],
   'name':['Buenos Aires', 'Paris', 'Melbourne', 'St Petersbourg', 'Abidjan', 'Montreal', 'Nairobi', 'Salvador']})
df=df.set_index('name')
df.head(10)
# Out:
#                    lon    lat
# name
# Buenos Aires    -58.00 -34.00
# Paris             2.00  49.00
# Melbourne       145.00 -38.00
# St Petersbourg   30.32  59.93
# Abidjan          -4.03   5.33
# Montreal        -73.57  45.52
# Nairobi          36.82  -1.29
# Salvador        -38.50 -12.97

# %% [markdown]
# We can compare the embeddings to the original data:

# %%
plot_points(df,title='original dataset')

plot_points(df_t,color='blue',title='Embedded Coordinates using Euclidean distance ')
# Out:
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))

# %% [markdown]
# We see the longitude relationship persevered, but the latitude seems to be distorted. This is because MDS preserves the stress relationship between data points. We can verify this by examining the clusters in the embedded coordinates.
#
# By examining the embedded coordinates, we see three groups or clusters. If we examine the distance dataframe, we see these groups are near each other. For example, Melbourne and Buenos Aires have a distance of four, this corresponds to the cluster of the cities at the bottom. Similarly, if you examine the relationship between Paris, St Petersbourg and Montreal, you see they are near each other. The same relation holds for the rest of the other cities.

# %% [markdown]
# ### Example 1
#
# In this case, we can recreate the distance dataframe using `pdist`. This calculates the Pairwise distances between data points in df. We then apply `squareform` that converts the result to a square-form distance matrix:
#
# $\sqrt{(lon_i-lon_j)^2 + (lat_i-lat_j)^2 }$

# %%
from scipy.spatial.distance import squareform, pdist

distance=pd.DataFrame(squareform(pdist(df.iloc[:, 1:])), columns=df.index, index=df.index)

# %% [markdown]
# We see MDS clusters on the distance matrix; unlike the principal component analysis, we can apply different distances. In the following  lines of code, we use other distance metrics on the longitude and latitude of different cities, then apply MDS. We plot out the results and see each distance has its own unique property.

# %%
dist=['cosine','cityblock','seuclidean','sqeuclidean','cosine','hamming','jaccard','chebyshev','canberra','braycurtis']
plot_points(df,title='original dataset')
for d in dist:

    distance=pd.DataFrame(squareform(pdist(df.iloc[:, 1:],metric=d)), columns=df.index, index=df.index)

    embedding =  MDS(dissimilarity='precomputed', random_state=0,n_components=2)
    X_transformed = embedding.fit_transform(distance)
    df_t=pd.DataFrame(X_transformed , columns=df.columns, index=df.index)

    plot_points(df_t,title='Embedded Coordinates using '+d ,color='blue')
# Out:
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: divide by zero encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# ...
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))

# %% [markdown]
# ## Non-Metric MDS

# %% [markdown]
# In  Non-Metric MDS, we apply a function $f(.)$, a distance metric, $d(z_i,z_j)$, for the distances between the points in the embedding space.  $f(.)$ is a monotonic function. This means it's always increasing, this preserves the order of the distance. For example, if one distance is larger before applying the function, it will still be larger after applying the function.

# %% [markdown]
# $\text{Stress}*D(z\_1,z\_2,...,z_N)=\Biggl(\frac{\sum*{i\ne j=1,...,N}\bigl(f(d(z_i,z_j))-d\_{i,j}\bigr)^2}{\sum d\_{i,j}^2}\Biggl)^{1/2}$

# %% [markdown]
# To  perform non-metric MDS , we first set `metric` to False.

# %%
metric=False
embedding =  MDS(dissimilarity='precomputed',n_components=2,metric=metric,random_state=0)

# %% [markdown]
# We then apply `fit_transform()` to the data from array distance that fits the model and returns the embedded coordinates, and convert it to a dataframe:

# %%
X_transformed = embedding.fit_transform(distance)
df_t=pd.DataFrame(X_transformed , columns=df.columns, index=df.index)
df_t.head(8)
# Out:
#                      lon       lat
# name
# Buenos Aires   -0.482760 -0.171638
# Paris           0.378508  0.179576
# Melbourne      -0.442890 -0.223888
# St Petersbourg  0.305767  0.254633
# Abidjan         0.533921 -0.171974
# Montreal        0.376625  0.129922
# Nairobi        -0.184670  0.258346
# Salvador       -0.507163 -0.285708

# %% [markdown]
# Non-metric MDS does better at preserving the horizontal scale, but the cities are negatively scaled in the longitudinal direction. At the same time, some cities like Paris and Montreal seem to have a different relationship  in the latitudinal direction.

# %%
plot_points(df,title='original dataset')

plot_points(df_t,color='blue',title='Embedded Coordinates using Euclidean distance ')
# Out:
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))

# %% [markdown]
# We can also apply different distances to Non-Metric MDS.

# %%
# We can also apply different distances to Non-Metric MDS.
# Chúng ta cũng có thể áp dụng các khoảng cách khác nhau cho Non-Metric MDS.

# Excluding 'hamming' and 'jaccard' as they caused issues in the previous run
dist=['cosine','cityblock','seuclidean','sqeuclidean','chebyshev','canberra','braycurtis']
# Định nghĩa danh sách các tên thước đo khoảng cách, loại bỏ các thước đo gây lỗi trước đó
plot_points(df,title='original dataset')
# Vẽ đồ thị cho dữ liệu gốc
metric=False
# Đặt biến metric thành False để sử dụng Non-Metric MDS
for d in dist:
    # Lặp qua từng thước đo khoảng cách trong danh sách dist

    distance=pd.DataFrame(squareform(pdist(df.iloc[:, 1:],metric=d)), columns=df.index, index=df.index)
    # Tính ma trận khoảng cách theo cặp sử dụng thước đo khoảng cách hiện tại
    print(f"Distance matrix using {d} metric:\n{distance.head()}")
    # In ra 5 dòng đầu tiên của ma trận khoảng cách để kiểm tra
    embedding =  MDS(dissimilarity='precomputed', random_state=0,n_components=2,metric=False)
    # Tạo đối tượng MDS mới với dissimilarity='precomputed', 2 thành phần, metric=False (Non-Metric MDS) và random_state=0
    X_transformed = embedding.fit_transform(distance)
    # Áp dụng MDS lên ma trận khoảng cách để biến đổi dữ liệu
    df_t=pd.DataFrame(X_transformed , columns=df.columns, index=df.index)
    # Tạo DataFrame mới từ kết quả biến đổi

    plot_points(df_t,title='Embedded Coordinates using '+d ,color='blue')
    # Vẽ đồ thị cho dữ liệu đã nhúng với tiêu đề chỉ ra thước đo khoảng cách được sử dụng
# Out:
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# Distance matrix using cosine metric:
# name            Buenos Aires  Paris  Melbourne  St Petersbourg  Abidjan  \
# name
# Buenos Aires             0.0    2.0        0.0             2.0      2.0
# Paris                    2.0    0.0        2.0             0.0      0.0
# Melbourne                0.0    2.0        0.0             2.0      2.0
# St Petersbourg           2.0    0.0        2.0             0.0      0.0
# Abidjan                  2.0    0.0        2.0             0.0      0.0
#
# name            Montreal  Nairobi  Salvador
# name
# Buenos Aires         2.0      0.0       0.0
# Paris                0.0      2.0       2.0
# Melbourne            2.0      0.0       0.0
# St Petersbourg       0.0      2.0       2.0
# Abidjan              0.0      2.0       2.0
# Distance matrix using cityblock metric:
# name            Buenos Aires  Paris  Melbourne  St Petersbourg  Abidjan  \
# name
# Buenos Aires            0.00  83.00       4.00           93.93    39.33
# Paris                  83.00   0.00      87.00           10.93    43.67
# Melbourne               4.00  87.00       0.00           97.93    43.33
# St Petersbourg         93.93  10.93      97.93            0.00    54.60
# Abidjan                39.33  43.67      43.33           54.60     0.00
#
# name            Montreal  Nairobi  Salvador
# name
# Buenos Aires       79.52    32.71     21.03
# Paris               3.48    50.29     61.97
# Melbourne          83.52    36.71     25.03
# St Petersbourg     14.41    61.22     72.90
# Abidjan            40.19     6.62     18.30
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# Distance matrix using seuclidean metric:
# name            Buenos Aires     Paris  Melbourne  St Petersbourg   Abidjan  \
# name
# Buenos Aires        0.000000  2.175691   0.104853        2.462200  1.030963
# Paris               2.175691  0.000000   2.280543        0.286510  1.144728
# Melbourne           0.104853  2.280543   0.000000        2.567053  1.135815
# St Petersbourg      2.462200  0.286510   2.567053        0.000000  1.431237
# Abidjan             1.030963  1.144728   1.135815        1.431237  0.000000
#
# name            Montreal   Nairobi  Salvador
# name
# Buenos Aires    2.084469  0.857432  0.551262
# Paris           0.091222  1.318259  1.624428
# Melbourne       2.189321  0.962284  0.656115
# St Petersbourg  0.377731  1.604768  1.910938
# Abidjan         1.053506  0.173531  0.479700
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# Distance matrix using sqeuclidean metric:
# name            Buenos Aires      Paris  Melbourne  St Petersbourg    Abidjan  \
# name
# Buenos Aires          0.0000  6889.0000    16.0000       8822.8449  1546.8489
# Paris              6889.0000     0.0000  7569.0000        119.4649  1907.0689
# Melbourne            16.0000  7569.0000     0.0000       9590.2849  1877.4889
# St Petersbourg     8822.8449   119.4649  9590.2849          0.0000  2981.1600
# Abidjan            1546.8489  1907.0689  1877.4889       2981.1600     0.0000
#
# name             Montreal    Nairobi   Salvador
# name
# Buenos Aires    6323.4304  1069.9441   442.2609
# Paris             12.1104  2529.0841  3840.2809
# Melbourne       6975.5904  1347.6241   626.5009
# St Petersbourg   207.6481  3747.8884  5314.4100
# Abidjan         1615.2361    43.8244   334.8900
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# Distance matrix using chebyshev metric:
# name            Buenos Aires  Paris  Melbourne  St Petersbourg  Abidjan  \
# name
# Buenos Aires            0.00  83.00       4.00           93.93    39.33
# Paris                  83.00   0.00      87.00           10.93    43.67
# Melbourne               4.00  87.00       0.00           97.93    43.33
# St Petersbourg         93.93  10.93      97.93            0.00    54.60
# Abidjan                39.33  43.67      43.33           54.60     0.00
#
# name            Montreal  Nairobi  Salvador
# name
# Buenos Aires       79.52    32.71     21.03
# Paris               3.48    50.29     61.97
# Melbourne          83.52    36.71     25.03
# St Petersbourg     14.41    61.22     72.90
# Abidjan            40.19     6.62     18.30
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# Distance matrix using canberra metric:
# name            Buenos Aires     Paris  Melbourne  St Petersbourg   Abidjan  \
# name
# Buenos Aires        0.000000  1.000000   0.055556        1.000000  1.000000
# Paris               1.000000  0.000000   1.000000        0.100340  0.803792
# Melbourne           0.055556  1.000000   0.000000        1.000000  1.000000
# St Petersbourg      1.000000  0.100340   1.000000        0.000000  0.836653
# Abidjan             1.000000  0.803792   1.000000        0.836653  0.000000
#
# name            Montreal   Nairobi  Salvador
# name
# Buenos Aires    1.000000  0.926891  0.447733
# Paris           0.036818  1.000000  1.000000
# Melbourne       1.000000  0.934334  0.491073
# St Petersbourg  0.136652  1.000000  1.000000
# Abidjan         0.790364  1.000000  1.000000
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# Distance matrix using braycurtis metric:
# name            Buenos Aires     Paris  Melbourne  St Petersbourg   Abidjan  \
# name
# Buenos Aires        0.000000  5.533333   0.055556        3.622445  1.371817
# Paris               5.533333  0.000000   7.909091        0.100340  0.803792
# Melbourne           0.055556  7.909091   0.000000        4.465572  1.326293
# St Petersbourg      3.622445  0.100340   4.465572        0.000000  0.836653
# Abidjan             1.371817  0.803792   1.326293        0.836653  0.000000
#
# name             Montreal   Nairobi  Salvador
# name
# Buenos Aires     6.902778  0.926891  0.447733
# Paris            0.036818  1.054077  1.719956
# Melbourne       11.106383  0.934334  0.491073
# St Petersbourg   0.136652  1.043997  1.552385
# Abidjan          0.790364  1.638614  2.395288
# /tmp/ipython-input-3160281655.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))

# %% [markdown]
# ## Dimensionality Reduction with MDS

# %% [markdown]
# MDS can also be used for Dimensionality Reduction. We just need to set $d\_{ij}=||x_i-x_j||\ $, where the dimension of $x_i$ is greater than $z_j$. Consider the  digits dataset that consists of 8x8 pixel images of digits ranging from 0 to 9.

# %%
from sklearn.datasets import load_digits

digits = load_digits(n_class=6)
X, y = digits.data, digits.target
n_samples, n_features = X.shape

# %% [markdown]
# We have 64 features or dimensions of $x_i$

# %%
print("samples:", n_samples, "features", n_features)
# Out:
# samples: 1083 features 64

# %% [markdown]
# We can plot out the different $x_i$  by converting them to a square array:

# %%
fig, axs = plt.subplots(nrows=10, ncols=10, figsize=(6, 6))
for idx, ax in enumerate(axs.ravel()):
    ax.imshow(X[idx].reshape((8, 8)), cmap=plt.cm.binary)
    ax.axis("off")
_ = fig.suptitle("A selection from the 64-dimensional digits dataset", fontsize=16)

# %% [markdown]
# We create an embedding object. As we are using the features X,  we set dissimilarity to `euclidean`, which is the default choice for the `dissimilarity` parameter in **sklearn.manifold.MDS**.

# %%
embedding=MDS(n_components=2, n_init=1, max_iter=120, n_jobs=2)

# %% [markdown]
# We can apply MDS to the data X, we will fit the model and make a prediction simultaneously using the <code>fit_transform</code> method.

# %%
X_transformed=embedding.fit_transform(X)

# %% [markdown]
# We plot the samples in the embedding space and overlay images of the digit and the colour representing the digit. We see that although there is some overlap, each cluster corresponds to a different digit, this is despite the fact that the method is unsupervised.

# %%
fig, ax = plt.subplots()
plot_embedding(X_transformed, "Metric MDS ", ax)
plt.show()

# %% [markdown]
# ### Exercise 1

# %% [markdown]
# In this exercise, you will apply metric  MDS using different distance metrics in the list dist to the digit dataset X_norm that has been normalized.

# %%
dist=['cosine','cityblock','hamming','jaccard','chebyshev','canberra','braycurtis']
scaler = MinMaxScaler()
X_norm=scaler.fit_transform(X)

# your code starts here#

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
#
#
# for d in dist:
#
#     distance=squareform(pdist(X_norm,metric=d))
#     print( d)
#
#     embedding =  MDS(dissimilarity='precomputed', random_state=0,n_components=2)
#     X_transformed = embedding.fit_transform(distance)
#     fig, ax = plt.subplots()
#     plot_embedding(X_transformed, "Metric MDS ", ax)
#     plt.show()
# ```
#
# </details>

# %% [markdown]
# ## T-Distributed Stochastic Neighbor Embedding (optional)

# %% [markdown]
# T-Distributed Stochastic Neighbor Embedding (TSNE) is a method for visualizing high-dimensional data. It usually works better than MDS for visualizing data. The method is based on probabilities, unlike MDS, you can't use the distances.

# %% [markdown]
# We apply the algorithm to the same dataset. As we see the setup is very similar.

# %%
from sklearn.manifold import TSNE

# %%
X_embedded = TSNE(n_components=2, init='random').fit_transform(X)

# %%
fig, ax = plt.subplots()
plot_embedding(X_embedded , "test", ax)
plt.show()

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01">Joseph Santarcangelo</a> has a PhD in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# [Roxanne Li](https://www.linkedin.com/in/roxanne-li/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2022-01-01) is a Data Science intern at IBM Skills Network, entering level-5 study in the Mathematics & Statistics undergraduate Coop program at McMaster University.

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By           | Change Description          |
# | ----------------- | ------- | -------------------- | --------------------------- |
# | 2022-02-29        | 0.1     | Joseph Santarcangelo | Complete Exercises' content |
# | 2022-05-20        | 0.1     | Roxanne Li           | Review and edit             |

# %% [markdown]
# # Task
# Đọc qua tất cả các code cell trong notebook và thêm comment bằng tiếng Việt để giải thích từng dòng code.

# %% [markdown]
# ## Review code cells
#
# ### Subtask:
# Iterate through all the code cells in the notebook.

# %% [markdown]
# ## Add comments
#
# ### Subtask:
# For each code cell, add comments in Vietnamese to explain each line of code.

# %% [markdown]
# **Reasoning**:
# Iterate through all the code cells and add Vietnamese comments to each line explaining its functionality.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# !mamba install -qy pandas==1.3.4 numpy==1.21.4 matplotlib==3.5.0 scikit-learn==0.20.1 scipy==1.7.3
# Note: If your environment doesn't support "!mamba install", use "!pip install"
# Tất cả các thư viện cần thiết cho lab này được liệt kê dưới đây. Các thư viện đã cài đặt sẵn trên Skills Network Labs được ghi chú.
# !mamba install -qy pandas==1.3.4 numpy==1.21.4 matplotlib==3.5.0 scikit-learn==0.20.1 scipy==1.7.3
# Lưu ý: Nếu môi trường của bạn không hỗ trợ "!mamba install", hãy sử dụng "!pip install"

# %% [markdown]
# **Reasoning**:
# Continue iterating through the code cells and add Vietnamese comments to each line explaining its functionality.

# %%
import warnings
# Bỏ qua các cảnh báo DeprecationWarning
warnings.filterwarnings("ignore", category=DeprecationWarning)

import pandas as pd
# Import thư viện pandas để xử lý dữ liệu
import numpy as np
# Import thư viện numpy để thực hiện các phép toán số học
from scipy.spatial.distance import euclidean, cityblock, cosine
# Import các hàm tính khoảng cách từ scipy
import sklearn.metrics.pairwise
# Import mô-đun pairwise từ sklearn.metrics
import seaborn as sns
# Import thư viện seaborn để trực quan hóa dữ liệu (mặc dù không được sử dụng trong các cell tiếp theo đã cho)
import folium
# Import thư viện folium để tạo bản đồ tương tác (mặc dù không được sử dụng trong các cell tiếp theo đã cho)
# Import matplotlib for 3d plotting:
# Import matplotlib để vẽ đồ thị 3D (mặc dù không được sử dụng trong các cell tiếp theo đã cho)
import matplotlib.pyplot as plt
# Import mô-đun pyplot từ matplotlib để vẽ đồ thị
from sklearn.preprocessing import  MinMaxScaler
# Import MinMaxScaler từ sklearn.preprocessing để chuẩn hóa dữ liệu
from matplotlib import offsetbox
# Import offsetbox từ matplotlib để tạo các hộp chú thích (được sử dụng trong hàm plot_embedding)
# Make matplotlib work in jupyter notebook
# Thiết lập backend của matplotlib để hiển thị hình ảnh trong Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# **Reasoning**:
# Continue iterating through the code cells and add Vietnamese comments to each line explaining its functionality.

# %%
def plot_points(df,color="red",title=""):
    # Định nghĩa hàm plot_points để vẽ các điểm trên đồ thị
    X=df['lon']
    # Lấy cột 'lon' (kinh độ) làm tọa độ x
    Y=df['lat']
    # Lấy cột 'lat' (vĩ độ) làm tọa độ y

    annotations=df.index
    # Lấy chỉ mục của DataFrame làm chú thích cho các điểm

    plt.figure(figsize=(8,6))
    # Tạo một figure mới với kích thước 8x6 inch
    plt.scatter(X,Y,s=100,color=color)
    # Vẽ biểu đồ phân tán với X và Y, kích thước điểm là 100, màu sắc được truyền vào
    plt.title(title)
    # Đặt tiêu đề cho đồ thị
    plt.xlabel("lat")
    # Đặt nhãn cho trục x là "lat" (có vẻ bị nhầm lẫn, nên là "lon")
    plt.ylabel("log")
    # Đặt nhãn cho trục y là "log" (có vẻ bị nhầm lẫn, nên là "lat")
    for i, label in enumerate(annotations):
        # Lặp qua từng điểm và chú thích của nó
        plt.annotate(label, (X[i], Y[i]))
        # Thêm chú thích (tên thành phố) vào vị trí của điểm
    plt.axis('equal')
    # Đặt tỷ lệ trục x và y bằng nhau
    plt.show()
    # Hiển thị đồ thị

# %% [markdown]
# **Reasoning**:
# Continue iterating through the code cells and add Vietnamese comments to each line explaining its functionality.

# %%
def plot_embedding(X, title, ax):
    # Định nghĩa hàm plot_embedding để vẽ các điểm trong không gian nhúng
    X = MinMaxScaler().fit_transform(X)
    # Chuẩn hóa dữ liệu X về phạm vi [0, 1]
    for digit in digits.target_names:
        # Lặp qua từng chữ số (0 đến 5)
        ax.scatter(
            *X[y == digit].T,
            # Vẽ biểu đồ phân tán cho các điểm thuộc về chữ số hiện tại
            marker=f"${digit}$",
            # Sử dụng chữ số làm ký hiệu cho điểm
            s=60,
            # Đặt kích thước của ký hiệu
            color=plt.cm.Dark2(digit),
            # Đặt màu sắc dựa trên chữ số
            alpha=0.425,
            # Đặt độ trong suốt
            zorder=2,
            # Đặt thứ tự vẽ (cao hơn các ảnh nền)
        )
    shown_images = np.array([[1.0, 1.0]])  # just something big
    # Khởi tạo một mảng để theo dõi các vị trí ảnh đã hiển thị (khởi tạo với giá trị lớn)
    for i in range(X.shape[0]):
        # Lặp qua từng điểm trong dữ liệu đã nhúng
        # plot every digit on the embedding
        # show an annotation box for a group of digits
        # Vẽ từng chữ số trên không gian nhúng và hiển thị hộp chú thích cho một nhóm chữ số
        dist = np.sum((X[i] - shown_images) ** 2, 1)
        # Tính khoảng cách bình phương nhỏ nhất giữa điểm hiện tại và các ảnh đã hiển thị
        if np.min(dist) < 4e-3:
            # Nếu khoảng cách nhỏ hơn ngưỡng (điểm quá gần ảnh đã hiển thị), bỏ qua
            continue
        shown_images = np.concatenate([shown_images, [X[i]]], axis=0)
        # Thêm vị trí của điểm hiện tại vào danh sách các ảnh đã hiển thị
        imagebox = offsetbox.AnnotationBbox(
            offsetbox.OffsetImage(digits.images[i], cmap=plt.cm.gray_r), X[i]
        )
        # Tạo một hộp chú thích chứa ảnh của chữ số
        imagebox.set(zorder=1)
        # Đặt thứ tự vẽ của hộp chú thích (thấp hơn các điểm)
        ax.add_artist(imagebox)
        # Thêm hộp chú thích vào đồ thị

    ax.set_title(title)
    # Đặt tiêu đề cho đồ thị
    ax.axis("off")
    # Tắt hiển thị trục

# %% [markdown]
# **Reasoning**:
# Continue iterating through the code cells and add Vietnamese comments to each line explaining its functionality.

# %%
distance=pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/distance.csv').set_index('name')
# Đọc dữ liệu khoảng cách từ file CSV trên URL và đặt cột 'name' làm chỉ mục
distance.head(8)
# Hiển thị 8 dòng đầu tiên của DataFrame khoảng cách
# Out:
#                 Buenos Aires  Paris  Melbourne  St Petersbourg  Abidjan  \
# name
# Buenos Aires            0.00  83.00       4.00           93.93    39.33
# Paris                  83.00   0.00      87.00           10.93    43.67
# Melbourne               4.00  87.00       0.00           97.93    43.33
# St Petersbourg         93.93  10.93      97.93            0.00    54.60
# Abidjan                39.33  43.67      43.33           54.60     0.00
# Montreal               79.52   3.48      83.52           14.41    40.19
# Nairobi                32.71  50.29      36.71           61.22     6.62
# Salvador               21.03  61.97      25.03           72.90    18.30
#
#                 Montreal  Nairobi  Salvador
# name
# Buenos Aires       79.52    32.71     21.03
# Paris               3.48    50.29     61.97
# Melbourne          83.52    36.71     25.03
# St Petersbourg     14.41    61.22     72.90
# Abidjan            40.19     6.62     18.30
# Montreal            0.00    46.81     58.49
# Nairobi            46.81     0.00     11.68
# Salvador           58.49    11.68      0.00

# %% [markdown]
# **Reasoning**:
# Continue iterating through the code cells and add Vietnamese comments to each line explaining its functionality.

# %%
from sklearn.manifold import MDS
# Import lớp MDS từ mô-đun manifold của sklearn

# %% [markdown]
# **Reasoning**:
# Continue iterating through the code cells and add Vietnamese comments to each line explaining its functionality.

# %%
embedding =  MDS(dissimilarity='precomputed',n_components=2,random_state=0,max_iter=300,eps=1e-3)
# Tạo một đối tượng MDS với các tham số:
# dissimilarity='precomputed': cho biết ma trận khoảng cách đã được tính toán trước
# n_components=2: giảm chiều về 2 chiều
# random_state=0: đặt seed cho trình tạo số ngẫu nhiên để kết quả có thể tái lập
# max_iter=300: số lần lặp tối đa của thuật toán SMACOF
# eps=1e-3: ngưỡng sai số tương đối để coi là hội tụ

# %% [markdown]
# **Reasoning**:
# Continue iterating through the code cells and add Vietnamese comments to each line explaining its functionality.

# %%
X_transformed = embedding.fit_transform(distance)
# Áp dụng mô hình MDS lên ma trận khoảng cách để tìm tọa độ nhúng (fit và transform dữ liệu)

# %% [markdown]
# ## Modify cells
#
# ### Subtask:
# Apply the changes to the code cells.

# %% [markdown]
# **Reasoning**:
# Apply the generated commented code to the code cells in the notebook to complete the subtask.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# !mamba install -qy pandas==1.3.4 numpy==1.21.4 matplotlib==3.5.0 scikit-learn==0.20.1 scipy==1.7.3
# Note: If your environment doesn't support "!mamba install", use "!pip install"
# Tất cả các thư viện cần thiết cho lab này được liệt kê dưới đây. Các thư viện đã cài đặt sẵn trên Skills Network Labs được ghi chú.
# !mamba install -qy pandas==1.3.4 numpy==1.21.4 matplotlib==3.5.0 scikit-learn==0.20.1 scipy==1.7.3
# Lưu ý: Nếu môi trường của bạn không hỗ trợ "!mamba install", hãy sử dụng "!pip install"

# %% [markdown]
# **Reasoning**:
# Apply the generated commented code to the next code cell in the notebook.

# %%
import warnings
# Bỏ qua các cảnh báo DeprecationWarning
warnings.filterwarnings("ignore", category=DeprecationWarning)

import pandas as pd
# Import thư viện pandas để xử lý dữ liệu
import numpy as np
# Import thư viện numpy để thực hiện các phép toán số học
from scipy.spatial.distance import euclidean, cityblock, cosine
# Import các hàm tính khoảng cách từ scipy
import sklearn.metrics.pairwise
# Import mô-đun pairwise từ sklearn.metrics
import seaborn as sns
# Import thư viện seaborn để trực quan hóa dữ liệu (mặc dù không được sử dụng trong các cell tiếp theo đã cho)
import folium
# Import thư viện folium để tạo bản đồ tương tác (mặc dù không được sử dụng trong các cell tiếp theo đã cho)
# Import matplotlib for 3d plotting:
# Import matplotlib để vẽ đồ thị 3D (mặc dù không được sử dụng trong các cell tiếp theo đã cho)
import matplotlib.pyplot as plt
# Import mô-đun pyplot từ matplotlib để vẽ đồ thị
from sklearn.preprocessing import  MinMaxScaler
# Import MinMaxScaler từ sklearn.preprocessing để chuẩn hóa dữ liệu
from matplotlib import offsetbox
# Import offsetbox từ matplotlib để tạo các hộp chú thích (được sử dụng trong hàm plot_embedding)
# Make matplotlib work in jupyter notebook
# Thiết lập backend của matplotlib để hiển thị hình ảnh trong Jupyter Notebook
# %matplotlib inline

# %% [markdown]
# **Reasoning**:
# Apply the generated commented code to the next code cell in the notebook.

# %%
def plot_points(df,color="red",title=""):
    # Định nghĩa hàm plot_points để vẽ các điểm trên đồ thị
    X=df['lon']
    # Lấy cột 'lon' (kinh độ) làm tọa độ x
    Y=df['lat']
    # Lấy cột 'lat' (vĩ độ) làm tọa độ y

    annotations=df.index
    # Lấy chỉ mục của DataFrame làm chú thích cho các điểm

    plt.figure(figsize=(8,6))
    # Tạo một figure mới với kích thước 8x6 inch
    plt.scatter(X,Y,s=100,color=color)
    # Vẽ biểu đồ phân tán với X và Y, kích thước điểm là 100, màu sắc được truyền vào
    plt.title(title)
    # Đặt tiêu đề cho đồ thị
    plt.xlabel("lat")
    # Đặt nhãn cho trục x là "lat" (có vẻ bị nhầm lẫn, nên là "lon")
    plt.ylabel("log")
    # Đặt nhãn cho trục y là "log" (có vẻ bị nhầm lẫn, nên là "lat")
    for i, label in enumerate(annotations):
        # Lặp qua từng điểm và chú thích của nó
        plt.annotate(label, (X[i], Y[i]))
        # Thêm chú thích (tên thành phố) vào vị trí của điểm
    plt.axis('equal')
    # Đặt tỷ lệ trục x và y bằng nhau
    plt.show()
    # Hiển thị đồ thị

# %% [markdown]
# **Reasoning**:
# Apply the generated commented code to the next code cell in the notebook.

# %%
def plot_embedding(X, title, ax):
    # Định nghĩa hàm plot_embedding để vẽ các điểm trong không gian nhúng
    X = MinMaxScaler().fit_transform(X)
    # Chuẩn hóa dữ liệu X về phạm vi [0, 1]
    for digit in digits.target_names:
        # Lặp qua từng chữ số (0 đến 5)
        ax.scatter(
            *X[y == digit].T,
            # Vẽ biểu đồ phân tán cho các điểm thuộc về chữ số hiện tại
            marker=f"${digit}$",
            # Sử dụng chữ số làm ký hiệu cho điểm
            s=60,
            # Đặt kích thước của ký hiệu
            color=plt.cm.Dark2(digit),
            # Đặt màu sắc dựa trên chữ số
            alpha=0.425,
            # Đặt độ trong suốt
            zorder=2,
            # Đặt thứ tự vẽ (cao hơn các ảnh nền)
        )
    shown_images = np.array([[1.0, 1.0]])  # just something big
    # Khởi tạo một mảng để theo dõi các vị trí ảnh đã hiển thị (khởi tạo với giá trị lớn)
    for i in range(X.shape[0]):
        # Lặp qua từng điểm trong dữ liệu đã nhúng
        # plot every digit on the embedding
        # show an annotation box for a group of digits
        # Vẽ từng chữ số trên không gian nhúng và hiển thị hộp chú thích cho một nhóm chữ số
        dist = np.sum((X[i] - shown_images) ** 2, 1)
        # Tính khoảng cách bình phương nhỏ nhất giữa điểm hiện tại và các ảnh đã hiển thị
        if np.min(dist) < 4e-3:
            # Nếu khoảng cách nhỏ hơn ngưỡng (điểm quá gần ảnh đã hiển thị), bỏ qua
            continue
        shown_images = np.concatenate([shown_images, [X[i]]], axis=0)
        # Thêm vị trí của điểm hiện tại vào danh sách các ảnh đã hiển thị
        imagebox = offsetbox.AnnotationBbox(
            offsetbox.OffsetImage(digits.images[i], cmap=plt.cm.gray_r), X[i]
        )
        # Tạo một hộp chú thích chứa ảnh của chữ số
        imagebox.set(zorder=1)
        # Đặt thứ tự vẽ của hộp chú thích (thấp hơn các điểm)
        ax.add_artist(imagebox)
        # Thêm hộp chú thích vào đồ thị

    ax.set_title(title)
    # Đặt tiêu đề cho đồ thị
    ax.axis("off")
    # Tắt hiển thị trục

# %% [markdown]
# **Reasoning**:
# Apply the generated commented code to the next code cell in the notebook.

# %%
distance=pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/distance.csv').set_index('name')
# Đọc dữ liệu khoảng cách từ file CSV trên URL và đặt cột 'name' làm chỉ mục
distance.head(8)
# Hiển thị 8 dòng đầu tiên của DataFrame khoảng cách
# Out:
#                 Buenos Aires  Paris  Melbourne  St Petersbourg  Abidjan  \
# name
# Buenos Aires            0.00  83.00       4.00           93.93    39.33
# Paris                  83.00   0.00      87.00           10.93    43.67
# Melbourne               4.00  87.00       0.00           97.93    43.33
# St Petersbourg         93.93  10.93      97.93            0.00    54.60
# Abidjan                39.33  43.67      43.33           54.60     0.00
# Montreal               79.52   3.48      83.52           14.41    40.19
# Nairobi                32.71  50.29      36.71           61.22     6.62
# Salvador               21.03  61.97      25.03           72.90    18.30
#
#                 Montreal  Nairobi  Salvador
# name
# Buenos Aires       79.52    32.71     21.03
# Paris               3.48    50.29     61.97
# Melbourne          83.52    36.71     25.03
# St Petersbourg     14.41    61.22     72.90
# Abidjan            40.19     6.62     18.30
# Montreal            0.00    46.81     58.49
# Nairobi            46.81     0.00     11.68
# Salvador           58.49    11.68      0.00

# %% [markdown]
# **Reasoning**:
# Apply the generated commented code to the next code cell in the notebook.

# %%
from sklearn.manifold import MDS
# Import lớp MDS từ mô-đun manifold của sklearn

# %% [markdown]
# **Reasoning**:
# Apply the generated commented code to the next code cell in the notebook.

# %%
embedding =  MDS(dissimilarity='precomputed',n_components=2,random_state=0,max_iter=300,eps=1e-3)
# Tạo một đối tượng MDS với các tham số:
# dissimilarity='precomputed': cho biết ma trận khoảng cách đã được tính toán trước
# n_components=2: giảm chiều về 2 chiều
# random_state=0: đặt seed cho trình tạo số ngẫu nhiên để kết quả có thể tái lập
# max_iter=300: số lần lặp tối đa của thuật toán SMACOF
# eps=1e-3: ngưỡng sai số tương đối để coi là hội tụ

# %% [markdown]
# **Reasoning**:
# Apply the generated commented code to the next code cell in the notebook.

# %%
X_transformed = embedding.fit_transform(distance)
# Áp dụng mô hình MDS lên ma trận khoảng cách để tìm tọa độ nhúng (fit và transform dữ liệu)

# %% [markdown]
# ## Modify cells
#
# ### Subtask:
# Apply the changes to the code cells.

# %% [markdown]
# **Reasoning**:
# Apply the generated Vietnamese comments to the remaining code cells in the notebook.

# %%
# We then plot the coordinates as an 'X_transformed'  approximation of the longitude and latitude.
# Sau đó, chúng ta vẽ các tọa độ như một phép xấp xỉ 'X_transformed' của kinh độ và vĩ độ.
df_t=pd.DataFrame(X_transformed , columns=["lon","lat"], index=distance.columns)
# Tạo DataFrame mới từ X_transformed với cột 'lon', 'lat' và chỉ mục từ DataFrame khoảng cách
df_t.head(8)
# Hiển thị 8 dòng đầu tiên của DataFrame df_t
# Out:
#                       lon        lat
# Buenos Aires   -11.186300 -41.802565
# Paris            9.513638  38.732017
# Melbourne       -9.292359 -46.088042
# St Petersbourg  16.549167  47.746633
# Abidjan         -1.608445  -3.575219
# Montreal         7.328738  35.794751
# Nairobi         -3.001616 -10.072240
# Salvador        -8.302824 -20.735334

# %% [markdown]
# **Reasoning**:
# Continue applying the generated Vietnamese comments to the next code cell.

# %%
# We can also obtain the embeddings using the attribute `embedding_`.
# Chúng ta cũng có thể lấy được các nhúng bằng cách sử dụng thuộc tính `embedding_`.
embedding.embedding_
# Truy cập thuộc tính embedding_ của đối tượng MDS để xem các tọa độ nhúng
# Out:
# array([[-11.18630004, -41.80256455],
#        [  9.5136384 ,  38.73201664],
#        [ -9.2923592 , -46.08804169],
#        [ 16.54916736,  47.74663293],
#        [ -1.60844493,  -3.57521947],
#        [  7.3287376 ,  35.79475057],
#        [ -3.00161566, -10.07223994],
#        [ -8.30282353, -20.7353345 ]])

# %% [markdown]
# **Reasoning**:
# Continue applying the generated Vietnamese comments to the next code cell.

# %%
# We can obtain the stress (sum of squared distance of the disparities and the distances for all constrained points).
# Chúng ta có thể lấy được stress (tổng bình phương khoảng cách của sự khác biệt và khoảng cách cho tất cả các điểm bị ràng buộc).
embedding.stress_
# Truy cập thuộc tính stress_ của đối tượng MDS để xem giá trị stress
# Out:
# np.float64(2.417240800968404)

# %% [markdown]
# **Reasoning**:
# Continue applying the generated Vietnamese comments to the next code cell.

# %%
# Finally, we will use the pairwise `dissimilarity_matrix_` function.
# Cuối cùng, chúng ta sẽ sử dụng hàm `dissimilarity_matrix_` theo cặp.
embedding.dissimilarity_matrix_
# Truy cập thuộc tính dissimilarity_matrix_ của đối tượng MDS để xem ma trận khác biệt tính toán
# Out:
# array([[ 0.  , 83.  ,  4.  , 93.93, 39.33, 79.52, 32.71, 21.03],
#        [83.  ,  0.  , 87.  , 10.93, 43.67,  3.48, 50.29, 61.97],
#        [ 4.  , 87.  ,  0.  , 97.93, 43.33, 83.52, 36.71, 25.03],
#        [93.93, 10.93, 97.93,  0.  , 54.6 , 14.41, 61.22, 72.9 ],
#        [39.33, 43.67, 43.33, 54.6 ,  0.  , 40.19,  6.62, 18.3 ],
#        [79.52,  3.48, 83.52, 14.41, 40.19,  0.  , 46.81, 58.49],
#        [32.71, 50.29, 36.71, 61.22,  6.62, 46.81,  0.  , 11.68],
#        [21.03, 61.97, 25.03, 72.9 , 18.3 , 58.49, 11.68,  0.  ]])

# %% [markdown]
# **Reasoning**:
# Continue applying the generated Vietnamese comments to the next code cell.

# %%
# Let’s compare the embeddings  to the longitude and latitude of each city.
# Hãy so sánh các nhúng với kinh độ và vĩ độ của từng thành phố.

# Make a data frame with dots to show on the map
# Tạo một DataFrame với các điểm để hiển thị trên bản đồ
df = pd.DataFrame({
   'lon':[-58, 2, 145, 30.32, -4.03, -73.57, 36.82, -38.5],
   'lat':[-34, 49, -38, 59.93, 5.33, 45.52, -1.29, -12.97],
   'name':['Buenos Aires', 'Paris', 'Melbourne', 'St Petersbourg', 'Abidjan', 'Montreal', 'Nairobi', 'Salvador']})
# Tạo DataFrame với dữ liệu kinh độ, vĩ độ và tên các thành phố
df=df.set_index('name')
# Đặt cột 'name' làm chỉ mục
df.head(10)
# Hiển thị 10 dòng đầu tiên của DataFrame df
# Out:
#                    lon    lat
# name
# Buenos Aires    -58.00 -34.00
# Paris             2.00  49.00
# Melbourne       145.00 -38.00
# St Petersbourg   30.32  59.93
# Abidjan          -4.03   5.33
# Montreal        -73.57  45.52
# Nairobi          36.82  -1.29
# Salvador        -38.50 -12.97

# %% [markdown]
# **Reasoning**:
# Continue applying the generated Vietnamese comments to the next code cell which plots the original and embedded coordinates.

# %%
# We can compare the embeddings to the original data:
# Chúng ta có thể so sánh các nhúng với dữ liệu gốc:

plot_points(df,title='original dataset')
# Gọi hàm plot_points để vẽ dữ liệu gốc với tiêu đề 'original dataset'

plot_points(df_t,color='blue',title='Embedded Coordinates using Euclidean distance ')
# Gọi hàm plot_points để vẽ dữ liệu nhúng với màu xanh dương và tiêu đề 'Embedded Coordinates using Euclidean distance '
# Out:
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))

# %% [markdown]
# **Reasoning**:
# Continue applying the generated Vietnamese comments to the next code cell which calculates the distance matrix using pdist.

# %%
# In this case, we can recreate the distance dataframe using `pdist`. This calculates the Pairwise distances between data points in df. We then apply `squareform` that converts the result to a square-form distance matrix:
# Trong trường hợp này, chúng ta có thể tạo lại DataFrame khoảng cách bằng cách sử dụng `pdist`. Hàm này tính khoảng cách theo cặp giữa các điểm dữ liệu trong df. Sau đó, chúng ta áp dụng `squareform` để chuyển kết quả thành ma trận khoảng cách dạng vuông:

# $\sqrt{(lon_i-lon_j)^2 + (lat_i-lat_j)^2 }$

from scipy.spatial.distance import squareform, pdist
# Import hàm squareform và pdist từ scipy.spatial.distance

distance=pd.DataFrame(squareform(pdist(df.iloc[:, 1:])), columns=df.index, index=df.index)
# Tính khoảng cách Euclidean theo cặp giữa các cột từ chỉ mục 1 trở đi (lat và lon) trong df, chuyển kết quả thành ma trận vuông và tạo DataFrame khoảng cách mới

# %% [markdown]
# **Reasoning**:
# Continue applying the generated Vietnamese comments to the next code cell which applies MDS with different distance metrics.

# %%
# We see MDS clusters on the distance matrix; unlike the principal component analysis, we can apply different distances. In the following  lines of code, we use other distance metrics on the longitude and latitude of different cities, then apply MDS. We plot out the results and see each distance has its own unique property.
# Chúng ta thấy MDS tạo ra các cụm trên ma trận khoảng cách; không giống như phân tích thành phần chính, chúng ta có thể áp dụng các khoảng cách khác nhau. Trong các dòng code sau, chúng ta sử dụng các thước đo khoảng cách khác nhau trên kinh độ và vĩ độ của các thành phố khác nhau, sau đó áp dụng MDS. Chúng ta vẽ kết quả và thấy mỗi khoảng cách có một thuộc tính độc đáo riêng.

dist=['cosine','cityblock','seuclidean','sqeuclidean','cosine','hamming','jaccard','chebyshev','canberra','braycurtis']
# Định nghĩa danh sách các tên thước đo khoảng cách
plot_points(df,title='original dataset')
# Vẽ đồ thị cho dữ liệu gốc

for d in dist:
    # Lặp qua từng thước đo khoảng cách trong danh sách dist

    distance=pd.DataFrame(squareform(pdist(df.iloc[:, 1:],metric=d)), columns=df.index, index=df.index)
    # Tính ma trận khoảng cách theo cặp sử dụng thước đo khoảng cách hiện tại
    embedding =  MDS(dissimilarity='precomputed', random_state=0,n_components=2)
    # Tạo đối tượng MDS mới với dissimilarity='precomputed', 2 thành phần và random_state=0
    X_transformed = embedding.fit_transform(distance)
    # Áp dụng MDS lên ma trận khoảng cách để biến đổi dữ liệu
    df_t=pd.DataFrame(X_transformed , columns=df.columns, index=df.index)
    # Tạo DataFrame mới từ kết quả biến đổi

    plot_points(df_t,title='Embedded Coordinates using '+d ,color='blue')
    # Vẽ đồ thị cho dữ liệu đã nhúng với tiêu đề chỉ ra thước đo khoảng cách được sử dụng
# Out:
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: divide by zero encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# ...
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:162: RuntimeWarning: invalid value encountered in scalar divide
#   if (old_stress - stress / dis) < eps:
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py:166: RuntimeWarning: invalid value encountered in scalar divide
#   old_stress = stress / dis
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))

# %% [markdown]
# ## Modify cells
#
# ### Subtask:
# Apply the changes to the code cells.

# %% [markdown]
# **Reasoning**:
# Continue applying the generated commented code to the remaining code cells in the notebook.

# %%
# To  perform non-metric MDS , we first set `metric` to False.
# Để thực hiện Non-Metric MDS, trước tiên chúng ta đặt `metric` thành False.
metric=False
# Đặt biến metric thành False để sử dụng Non-Metric MDS
embedding =  MDS(dissimilarity='precomputed',n_components=2,metric=metric,random_state=0)
# Tạo đối tượng MDS mới với dissimilarity='precomputed', 2 thành phần, metric=False (Non-Metric MDS) và random_state=0

# %% [markdown]
# **Reasoning**:
# Apply the generated commented code to the next code cell.

# %%
# We then apply `fit_transform()` to the data from array distance that fits the model and returns the embedded coordinates, and convert it to a dataframe:
# Sau đó, chúng ta áp dụng `fit_transform()` cho dữ liệu từ mảng khoảng cách phù hợp với mô hình và trả về tọa độ nhúng, sau đó chuyển đổi nó thành DataFrame:
X_transformed = embedding.fit_transform(distance)
# Áp dụng MDS lên ma trận khoảng cách để biến đổi dữ liệu
df_t=pd.DataFrame(X_transformed , columns=df.columns, index=df.index)
# Tạo DataFrame mới từ kết quả biến đổi
df_t.head(8)
# Hiển thị 8 dòng đầu tiên của DataFrame df_t
# Out:
#                      lon       lat
# name
# Buenos Aires   -0.482760 -0.171638
# Paris           0.378508  0.179576
# Melbourne      -0.442890 -0.223888
# St Petersbourg  0.305767  0.254633
# Abidjan         0.533921 -0.171974
# Montreal        0.376625  0.129922
# Nairobi        -0.184670  0.258346
# Salvador       -0.507163 -0.285708

# %% [markdown]
# **Reasoning**:
# Apply the generated commented code to the next code cell.

# %%
# Non-metric MDS does better at preserving the horizontal scale, but the cities are negatively scaled in the longitudinal direction. At the same time, some cities like Paris and Montreal seem to have a different relationship  in the latitudinal direction.
# Non-metric MDS làm tốt hơn trong việc bảo toàn tỷ lệ ngang, nhưng các thành phố bị co giãn âm theo chiều kinh độ. Đồng thời, một số thành phố như Paris và Montreal dường như có mối quan hệ khác nhau theo chiều vĩ độ.

plot_points(df,title='original dataset')
# Vẽ đồ thị cho dữ liệu gốc

plot_points(df_t,color='blue',title='Embedded Coordinates using Euclidean distance ')
# Vẽ đồ thị cho dữ liệu đã nhúng bằng Non-Metric MDS với màu xanh dương
# Out:
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))

# %% [markdown]
# **Reasoning**:
# Apply the generated commented code to the next code cell.

# %%
# We can also apply different distances to Non-Metric MDS.
# Chúng ta cũng có thể áp dụng các khoảng cách khác nhau cho Non-Metric MDS.

dist=['cosine','cityblock','seuclidean','sqeuclidean','cosine','hamming','jaccard','chebyshev','canberra','braycurtis']
# Định nghĩa danh sách các tên thước đo khoảng cách
plot_points(df,title='original dataset')
# Vẽ đồ thị cho dữ liệu gốc
metric=False
# Đặt biến metric thành False để sử dụng Non-Metric MDS
for d in dist:
    # Lặp qua từng thước đo khoảng cách trong danh sách dist

    distance=pd.DataFrame(squareform(pdist(df.iloc[:, 1:],metric=d)), columns=df.index, index=df.index)
    # Tính ma trận khoảng cách theo cặp sử dụng thước đo khoảng cách hiện tại
    embedding =  MDS(dissimilarity='precomputed', random_state=0,n_components=2,metric=False)
    # Tạo đối tượng MDS mới với dissimilarity='precomputed', 2 thành phần, metric=False (Non-Metric MDS) và random_state=0
    X_transformed = embedding.fit_transform(distance)
    # Áp dụng MDS lên ma trận khoảng cách để biến đổi dữ liệu
    df_t=pd.DataFrame(X_transformed , columns=df.columns, index=df.index)
    # Tạo DataFrame mới từ kết quả biến đổi

    plot_points(df_t,title='Embedded Coordinates using '+d ,color='blue')
    # Vẽ đồ thị cho dữ liệu đã nhúng với tiêu đề chỉ ra thước đo khoảng cách được sử dụng
# Out:
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1514604415.py in <cell line: 0>()
#      15     embedding =  MDS(dissimilarity='precomputed', random_state=0,n_components=2,metric=False)
#      16     # Tạo đối tượng MDS mới với dissimilarity='precomputed', 2 thành phần, metric=False (Non-Metric MDS) và random_state=0
# ---> 17     X_transformed = embedding.fit_transform(distance)
#      18     # Áp dụng MDS lên ma trận khoảng cách để biến đổi dữ liệu
#      19     df_t=pd.DataFrame(X_transformed , columns=df.columns, index=df.index)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py in fit_transform(self, X, y, init)
#     642             self.dissimilarity_matrix_ = euclidean_distances(X)
#     643
# --> 644         self.embedding_, self.stress_, self.n_iter_ = smacof(
#     645             self.dissimilarity_matrix_,
#     646             metric=self.metric,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     187             global_skip_validation = get_config()["skip_parameter_validation"]
#     188             if global_skip_validation:
# --> 189                 return func(*args, **kwargs)
#     190
#     191             func_sig = signature(func)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py in smacof(dissimilarities, metric, n_components, init, n_init, n_jobs, max_iter, verbose, eps, random_state, return_n_iter, normalized_stress)
#     351     if effective_n_jobs(n_jobs) == 1:
#     352         for it in range(n_init):
# --> 353             pos, stress, n_iter_ = _smacof_single(
#     354                 dissimilarities,
#     355                 metric=metric,
#
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_mds.py in _smacof_single(dissimilarities, metric, n_components, init, max_iter, verbose, eps, random_state, normalized_stress)
#     137
#     138             # Compute the disparities using a monotonic regression
# --> 139             disparities_flat = ir.fit_transform(sim_flat_w, dis_flat_w)
#     140             disparities = dis_flat.copy()
#     141             disparities[sim_flat != 0] = disparities_flat
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     919         else:
#     920             # fit method of arity 2 (supervised transformation)
# --> 921             return self.fit(X, y, **fit_params).transform(X)
#     922
#     923
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/isotonic.py in fit(self, X, y, sample_weight)
#     391         """
#     392         check_params = dict(accept_sparse=False, ensure_2d=False)
# --> 393         X = check_array(
#     394             X, input_name="X", dtype=[np.float64, np.float32], **check_params
#     395         )
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1128         n_samples = _num_samples(array)
#    1129         if n_samples < ensure_min_samples:
# -> 1130             raise ValueError(
#    1131                 "Found array with %d sample(s) (shape=%s) while a"
#    1132                 " minimum of %d is required%s."
#
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.

# %% [markdown]
# **Reasoning**:
# An error occurred during the previous execution, likely due to one of the distance metrics resulting in an empty distance matrix. I will regenerate the code block for applying different distance metrics in Non-Metric MDS, excluding the metrics that caused the error and printing the distance matrix before applying MDS to help debug.

# %%
# We can also apply different distances to Non-Metric MDS.
# Chúng ta cũng có thể áp dụng các khoảng cách khác nhau cho Non-Metric MDS.

# Excluding 'hamming' and 'jaccard' as they caused issues in the previous run
dist=['cosine','cityblock','seuclidean','sqeuclidean','chebyshev','canberra','braycurtis']
# Định nghĩa danh sách các tên thước đo khoảng cách, loại bỏ các thước đo gây lỗi trước đó
plot_points(df,title='original dataset')
# Vẽ đồ thị cho dữ liệu gốc
metric=False
# Đặt biến metric thành False để sử dụng Non-Metric MDS
for d in dist:
    # Lặp qua từng thước đo khoảng cách trong danh sách dist

    distance=pd.DataFrame(squareform(pdist(df.iloc[:, 1:],metric=d)), columns=df.index, index=df.index)
    # Tính ma trận khoảng cách theo cặp sử dụng thước đo khoảng cách hiện tại
    print(f"Distance matrix using {d} metric:\n{distance.head()}")
    # In ra 5 dòng đầu tiên của ma trận khoảng cách để kiểm tra
    embedding =  MDS(dissimilarity='precomputed', random_state=0,n_components=2,metric=False)
    # Tạo đối tượng MDS mới với dissimilarity='precomputed', 2 thành phần, metric=False (Non-Metric MDS) và random_state=0
    X_transformed = embedding.fit_transform(distance)
    # Áp dụng MDS lên ma trận khoảng cách để biến đổi dữ liệu
    df_t=pd.DataFrame(X_transformed , columns=df.columns, index=df.index)
    # Tạo DataFrame mới từ kết quả biến đổi

    plot_points(df_t,title='Embedded Coordinates using '+d ,color='blue')
    # Vẽ đồ thị cho dữ liệu đã nhúng với tiêu đề chỉ ra thước đo khoảng cách được sử dụng
# Out:
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# Distance matrix using cosine metric:
# name            Buenos Aires  Paris  Melbourne  St Petersbourg  Abidjan  \
# name
# Buenos Aires             0.0    2.0        0.0             2.0      2.0
# Paris                    2.0    0.0        2.0             0.0      0.0
# Melbourne                0.0    2.0        0.0             2.0      2.0
# St Petersbourg           2.0    0.0        2.0             0.0      0.0
# Abidjan                  2.0    0.0        2.0             0.0      0.0
#
# name            Montreal  Nairobi  Salvador
# name
# Buenos Aires         2.0      0.0       0.0
# Paris                0.0      2.0       2.0
# Melbourne            2.0      0.0       0.0
# St Petersbourg       0.0      2.0       2.0
# Abidjan              0.0      2.0       2.0
# Distance matrix using cityblock metric:
# name            Buenos Aires  Paris  Melbourne  St Petersbourg  Abidjan  \
# name
# Buenos Aires            0.00  83.00       4.00           93.93    39.33
# Paris                  83.00   0.00      87.00           10.93    43.67
# Melbourne               4.00  87.00       0.00           97.93    43.33
# St Petersbourg         93.93  10.93      97.93            0.00    54.60
# Abidjan                39.33  43.67      43.33           54.60     0.00
#
# name            Montreal  Nairobi  Salvador
# name
# Buenos Aires       79.52    32.71     21.03
# Paris               3.48    50.29     61.97
# Melbourne          83.52    36.71     25.03
# St Petersbourg     14.41    61.22     72.90
# Abidjan            40.19     6.62     18.30
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# Distance matrix using seuclidean metric:
# name            Buenos Aires     Paris  Melbourne  St Petersbourg   Abidjan  \
# name
# Buenos Aires        0.000000  2.175691   0.104853        2.462200  1.030963
# Paris               2.175691  0.000000   2.280543        0.286510  1.144728
# Melbourne           0.104853  2.280543   0.000000        2.567053  1.135815
# St Petersbourg      2.462200  0.286510   2.567053        0.000000  1.431237
# Abidjan             1.030963  1.144728   1.135815        1.431237  0.000000
#
# name            Montreal   Nairobi  Salvador
# name
# Buenos Aires    2.084469  0.857432  0.551262
# Paris           0.091222  1.318259  1.624428
# Melbourne       2.189321  0.962284  0.656115
# St Petersbourg  0.377731  1.604768  1.910938
# Abidjan         1.053506  0.173531  0.479700
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# Distance matrix using sqeuclidean metric:
# name            Buenos Aires      Paris  Melbourne  St Petersbourg    Abidjan  \
# name
# Buenos Aires          0.0000  6889.0000    16.0000       8822.8449  1546.8489
# Paris              6889.0000     0.0000  7569.0000        119.4649  1907.0689
# Melbourne            16.0000  7569.0000     0.0000       9590.2849  1877.4889
# St Petersbourg     8822.8449   119.4649  9590.2849          0.0000  2981.1600
# Abidjan            1546.8489  1907.0689  1877.4889       2981.1600     0.0000
#
# name             Montreal    Nairobi   Salvador
# name
# Buenos Aires    6323.4304  1069.9441   442.2609
# Paris             12.1104  2529.0841  3840.2809
# Melbourne       6975.5904  1347.6241   626.5009
# St Petersbourg   207.6481  3747.8884  5314.4100
# Abidjan         1615.2361    43.8244   334.8900
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# Distance matrix using chebyshev metric:
# name            Buenos Aires  Paris  Melbourne  St Petersbourg  Abidjan  \
# name
# Buenos Aires            0.00  83.00       4.00           93.93    39.33
# Paris                  83.00   0.00      87.00           10.93    43.67
# Melbourne               4.00  87.00       0.00           97.93    43.33
# St Petersbourg         93.93  10.93      97.93            0.00    54.60
# Abidjan                39.33  43.67      43.33           54.60     0.00
#
# name            Montreal  Nairobi  Salvador
# name
# Buenos Aires       79.52    32.71     21.03
# Paris               3.48    50.29     61.97
# Melbourne          83.52    36.71     25.03
# St Petersbourg     14.41    61.22     72.90
# Abidjan            40.19     6.62     18.30
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# Distance matrix using canberra metric:
# name            Buenos Aires     Paris  Melbourne  St Petersbourg   Abidjan  \
# name
# Buenos Aires        0.000000  1.000000   0.055556        1.000000  1.000000
# Paris               1.000000  0.000000   1.000000        0.100340  0.803792
# Melbourne           0.055556  1.000000   0.000000        1.000000  1.000000
# St Petersbourg      1.000000  0.100340   1.000000        0.000000  0.836653
# Abidjan             1.000000  0.803792   1.000000        0.836653  0.000000
#
# name            Montreal   Nairobi  Salvador
# name
# Buenos Aires    1.000000  0.926891  0.447733
# Paris           0.036818  1.000000  1.000000
# Melbourne       1.000000  0.934334  0.491073
# St Petersbourg  0.136652  1.000000  1.000000
# Abidjan         0.790364  1.000000  1.000000
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))
# Distance matrix using braycurtis metric:
# name            Buenos Aires     Paris  Melbourne  St Petersbourg   Abidjan  \
# name
# Buenos Aires        0.000000  5.533333   0.055556        3.622445  1.371817
# Paris               5.533333  0.000000   7.909091        0.100340  0.803792
# Melbourne           0.055556  7.909091   0.000000        4.465572  1.326293
# St Petersbourg      3.622445  0.100340   4.465572        0.000000  0.836653
# Abidjan             1.371817  0.803792   1.326293        0.836653  0.000000
#
# name             Montreal   Nairobi  Salvador
# name
# Buenos Aires     6.902778  0.926891  0.447733
# Paris            0.036818  1.054077  1.719956
# Melbourne       11.106383  0.934334  0.491073
# St Petersbourg   0.136652  1.043997  1.552385
# Abidjan          0.790364  1.638614  2.395288
# /tmp/ipython-input-374550116.py:23: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.annotate(label, (X[i], Y[i]))

# %% [markdown]
# **Reasoning**:
# Apply the generated commented code to the next code cell.

# %%
# We create an embedding object. As we are using the features X,  we set dissimilarity to `euclidean`, which is the default choice for the `dissimilarity` parameter in **sklearn.manifold.MDS**.
# Chúng ta tạo một đối tượng nhúng. Vì chúng ta đang sử dụng các đặc trưng X, chúng ta đặt dissimilarity là `euclidean`, đây là lựa chọn mặc định cho tham số `dissimilarity` trong **sklearn.manifold.MDS**.

embedding=MDS(n_components=2, n_init=1, max_iter=120, n_jobs=2)
# Tạo đối tượng MDS với 2 thành phần, 1 lần khởi tạo, tối đa 120 lần lặp và sử dụng 2 nhân CPU

# %% [markdown]
# **Reasoning**:
# Apply the generated commented code to the next code cell.

# %%
# We can apply MDS to the data X, we will fit the model and make a prediction simultaneously using the fit_transform method.
# Chúng ta có thể áp dụng MDS cho dữ liệu X, chúng ta sẽ fit mô hình và dự đoán đồng thời bằng cách sử dụng phương thức fit_transform.
X_transformed=embedding.fit_transform(X)
# Áp dụng MDS lên dữ liệu X để biến đổi nó thành không gian 2 chiều

# %% [markdown]
# **Reasoning**:
# The previous command failed because the variable `X` was not defined. This happened because the code block where `X` and `y` were loaded from the `digits` dataset was not executed. I need to execute that code block and then re-run the `fit_transform` step. I will regenerate the code block that loads the digits dataset and the subsequent code blocks for MDS on this dataset, including the plotting code, to ensure they are executed in the correct order.

# %%
# MDS can also be used for Dimensionality Reduction. We just need to set $d\_{ij}=||x_i-x_j||\ $, where the dimension of $x_i$ is greater than $z_j$. Consider the  digits dataset that consists of 8x8 pixel images of digits ranging from 0 to 9.
# MDS cũng có thể được sử dụng để giảm chiều dữ liệu. Chúng ta chỉ cần đặt $d\_{ij}=||x_i-x_j||\ $, trong đó chiều của $x_i$ lớn hơn $z_j$. Xem xét tập dữ liệu digits bao gồm các ảnh chữ số 8x8 pixel từ 0 đến 9.

from sklearn.datasets import load_digits
# Import hàm load_digits từ sklearn.datasets

digits = load_digits(n_class=6)
# Tải tập dữ liệu digits với 6 lớp (từ 0 đến 5)
X, y = digits.data, digits.target
# Gán dữ liệu đặc trưng vào X và nhãn vào y
n_samples, n_features = X.shape
# Lấy số lượng mẫu và số lượng đặc trưng

# We have 64 features or dimensions of $x_i$
# Chúng ta có 64 đặc trưng hoặc chiều của $x_i$
print("samples:", n_samples, "features", n_features)
# In ra số lượng mẫu và số lượng đặc trưng

# We can plot out the different $x_i$  by converting them to a square array:
# Chúng ta có thể vẽ các $x_i$ khác nhau bằng cách chuyển chúng thành mảng vuông:
fig, axs = plt.subplots(nrows=10, ncols=10, figsize=(6, 6))
# Tạo lưới 10x10 subplot
for idx, ax in enumerate(axs.ravel()):
    # Lặp qua từng subplot
    ax.imshow(X[idx].reshape((8, 8)), cmap=plt.cm.binary)
    # Hiển thị ảnh chữ số tương ứng trong subplot
    ax.axis("off")
    # Tắt hiển thị trục
_ = fig.suptitle("A selection from the 64-dimensional digits dataset", fontsize=16)
# Đặt tiêu đề cho toàn bộ figure

# We create an embedding object. As we are using the features X,  we set dissimilarity to `euclidean`, which is the default choice for the `dissimilarity` parameter in **sklearn.manifold.MDS**.
# Chúng ta tạo một đối tượng nhúng. Vì chúng ta đang sử dụng các đặc trưng X, chúng ta đặt dissimilarity là `euclidean`, đây là lựa chọn mặc định cho tham số `dissimilarity` trong **sklearn.manifold.MDS**.
embedding=MDS(n_components=2, n_init=1, max_iter=120, n_jobs=2)
# Tạo đối tượng MDS với 2 thành phần, 1 lần khởi tạo, tối đa 120 lần lặp và sử dụng 2 nhân CPU

# We can apply MDS to the data X, we will fit the model and make a prediction simultaneously using the fit_transform method.
# Chúng ta có thể áp dụng MDS cho dữ liệu X, chúng ta sẽ fit mô hình và dự đoán đồng thời bằng cách sử dụng phương thức fit_transform.
X_transformed=embedding.fit_transform(X)
# Áp dụng MDS lên dữ liệu X để biến đổi nó thành không gian 2 chiều

# We plot the samples in the embedding space and overlay images of the digit and the colour representing the digit. We see that although there is some overlap, each cluster corresponds to a different digit, this is despite the fact that the method is unsupervised.
# Chúng ta vẽ các mẫu trong không gian nhúng và phủ lên trên ảnh của chữ số và màu sắc đại diện cho chữ số. Chúng ta thấy rằng mặc dù có một số chồng chéo, mỗi cụm tương ứng với một chữ số khác nhau, điều này bất chấp thực tế là phương pháp này không có giám sát.
fig, ax = plt.subplots()
# Tạo một figure và axes mới
plot_embedding(X_transformed, "Metric MDS ", ax)
# Vẽ các điểm đã nhúng sử dụng hàm plot_embedding
plt.show()
# Hiển thị đồ thị
# Out:
# samples: 1083 features 64
